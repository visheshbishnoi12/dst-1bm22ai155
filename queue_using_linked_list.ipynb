# %%
class Node:
  def __init__(self,data):
    self.data = data
    self.next = None

class Queue:
  def __init__(self):
    self.front = None
    self.rear = None

  def enqueue(self,data):
    new = Node(data)
    if self.front is None:
      self.front = new
      self.rear = new
    else:
      self.rear.next = new
      self.rear = new

  def dequeue(self):
    if self.front is None:
      self.front = None
      self.rear = None
      print("queue is empty")
    elif self.front.next is None:
      removed_element = self.front.data
      print("Removed element- ",removed_element)
      self.front = None
      self.rear = None
    else:
      temp = self.front
      removed_element = self.front.data
      print("Removed element- ",removed_element)
      self.front = temp.next
      temp = None

  def display(self):
    if self.front is None:
      print("Queue is empty")
    else:
      print("Element are:")
      temp = self.front
      while temp is not None:
        print(" --> ",temp.data,end="")
        temp = temp.next
      print("\nFront of queue- ",self.front.data)
      print("Rear of queue- ",self.rear.data)

q = Queue()

while True:
  print("\n1.add \n2.delete111 \n3.Display \n4.Exit")
  optn = int(input("your option - "))
  if optn == 1:
    num = int(input("Enter the element- "))
    q.enqueue(num)
  elif optn == 2:
    q.dequeue()
  elif optn == 3:
    q.display()
  elif optn == 4:
    break
  else:
    print("Enter a correct operation")
# Out:
# 1.add
# 2.delete11
# 3.Display
# 4.Exit
# your option - 1
# Enter the element- 11
#
# 1.add
# 2.delete11
# 3.Display
# 4.Exit
# your option - 1
# Enter the element- 22
#
# 1.add
# 2.delete11
# 3.Display
# 4.Exit
# your option - 1
# Enter the element- 33
#
# 1.add
# 2.delete11
# 3.Display
# 4.Exit
# your option - 1
# Enter the element- 44
#
# 1.add
# 2.delete11
# 3.Display
# 4.Exit
# your option - 3
# Element are:
#  -->  11 -->  22 -->  33 -->  44
# Front of queue-  11
# Rear of queue-  44
#
# 1.add
# 2.delete11
# 3.Display
# 4.Exit
# your option - 2
# Removed element-  11
#
# 1.add
# 2.delete11
# 3.Display
# 4.Exit
# your option - 2
# Removed element-  22
#
# 1.add
# 2.delete11
# 3.Display
# 4.Exit
# your option - 3
# Element are:
#  -->  33 -->  44
# Front of queue-  33
# Rear of queue-  44
#
# 1.add
# 2.delete11
# 3.Display
# 4.Exit
# your option - 4
